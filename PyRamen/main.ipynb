# %%
import csv
import os

#Set resource directory
dir = "C:/GitBash/python-homework/PyRamen"

# Initalize paths
menu_file_path = os.path.join(dir, "menu_data.csv")
sales_file_path = os.path.join(dir, "sales_data.csv")
out_file = os.path.join(dir, "PyRamen.txt")

# variables, dict or lists definitions and initialization.
menu = []
sales = []
report = {}
rowCount = 0


#-------------------------------------------------------------------
# read menu data from csv file - sales_data.csv into a list 'menu'
#-------------------------------------------------------------------
with open(menu_file_path, 'r') as menu_file:
    menu_data = csv.reader(menu_file, delimiter = ',')     #Read the menu data csv file
    header = next(menu_data)                               #read first record in the csv file, which is a header record in this case
    ##print(f"header record-> {header}" )
    
    for i in menu_data:                                    #for loop to extract and append data from file MenuData 
        menu.append(i)                                     #Append the coten of 'csvData' into 'menu' list


#-------------------------------------------------------------------        
# read sales data from csv file - menu_data.csv into a list 'sales'
#-------------------------------------------------------------------
with open(sales_file_path, 'r') as sale_file:
    sales_data = csv.reader(sale_file, delimiter = ',')    #Read the menu data csv file
    header = next(sales_data)                              #read first record in the csv file, which is a header record in this case
    ##print(f"{header} <- this is the header" )
    
    for i in sales_data:                                   #for loop to extract and append data from file SalesData 
        sales.append(i)                                    #Append the coten of 'csvData' into 'sales' list


        
#-------------------------------------------------------------------------
# Load sales items into dictionary 'report along with key-value-pair
# Key = sales item from column 4
# value = "01-count": 0, "02-revenue": 0, "03-cogs": 0, "04-profit": 0
#-------------------------------------------------------------------------
for row in sales:
    quantity = row[3]                                      #Store quantity value from cloumn 3
    sales_item = row[4]                                    #Store sales item value from cloumn 4  

    #If the key-value-pair does not exist for sales item, then add to dictionary   
    if sales_item not in report:                        
        report[sales_item] = {"01-count": 0, "02-revenue": 0, "03-cogs": 0, "04-profit": 0}
        
    if sales_item in report:
        report[sales_item]["01-count"] += int(quantity)
        

#-----------------------------------------------------------------------------
# Calculation of Total revenue and cost. for each keys in dictionary 'report', 
# find the same key value in list 'menu' and extract unit price which is in 
# row 3. Then multiply unit price by Total count from dictionaty 'report' for
# the associate key. Using report to fnd key values in the list menu ensure that 
# every item in dict report is found because values in dict report are from 
# list sales.
#-----------------------------------------------------------------------------
#Initialize variables. 
menu_price = 0.0                #Hold menu price for found key value. From loop 2 - menu
menu_cost  = 0.0                #Hold cost of menu item for found key value. From loop 2 - menu
qty_sold   = 0                  #Hold total Qty sold for found key value. From loop 1 - report
revenue   = 0.0                 #Hold the revenue = menuPrice * qtySold. Calculated in loop 1
total_cost = 0.0                #Hold total cost = menuCost * qtySold. Calculated in loop 1


for key in report.keys():                               #For each key value in report
    for menu_row in menu:                               #Loop through meni list to find the key value from report
        if menu_row[0] == key:                          #Make sure key values are matching
            menu_price = menu_row[3]                    #Store unit price from menu
            menu_cost  = menu_row[4]                    #Store unit cost from menu 
            qty_sold = report[key]["01-count"]          #Store total quantity sold from report
            Found = True
    
    revenue = float(menu_price) * float(qty_sold)       #Revenue calculation
    total_cost = float(menu_cost) * float(qty_sold)     #Total cost calculation    
    report[key]["02-revenue"] = "${:,.2f}".format(float(menu_price) * float(qty_sold)) #Store revenue in dict report
    report[key]["03-cogs"] = "${:,.2f}".format(float(menu_cost) * float(qty_sold))     #Store cogs in dict report
    report[key]["04-profit"] = "${:,.2f}".format(float(revenue) - float(total_cost))   #Store profit in dict report
    

#Write the results to file - Analysis_output.txt
with open(out_file, 'w') as outFile:
    outFile.write("                                              Financial Analysis\n")
    outFile.write("                                               02-Python-PyBank\n")
    outFile.write("                                              Optional Exercise\n")
    outFile.write("                                             ---------------------\n")
    outFile.write("\n")
    for key in report:
        outFile.write(f"{key} {report[key]} \n")
    
    outFile.write("\n")
    outFile.write("                      * * * * * * * * * * * * E N D  O F  R E P O R T* * * * * * * * * * * * \n")
